# %%
import pandas as pd

import numpy as np

import synthpop.zone_synthesizer as zs

# %% [markdown]
# #### Specify sample data csv paths. See the files listed here for expected structure. Marginal tables require multi-indexed columns with category name and category value in levels 0 and 1 of the index. Sample file category columns should be labeled with corresponding category names and values in those columns should match the category value headers in the marginal table.

# %%
hh_marginal_file = './data/hh_marginals.csv'
person_marginal_file = './data/person_marginals.csv'
hh_sample_file = './data/household_sample.csv'
person_sample_file = './data/person_sample.csv'

# %%
def convert_to_str(margin, sample):
    colist = []
    for acol in margin.columns:
        colist.append(acol[0])
    colist = np.unique(colist)
    for acol in colist:
        if acol in sample.columns:
            sample[acol] = sample[acol].astype(str)
    return sample

# %% [markdown]
# #### Load and process input marginals and samples and geography crosswalk

# %%
hh_marg, p_marg, hh_sample, p_sample, xwalk = zs.load_data(hh_marginal_file, person_marginal_file, hh_sample_file, person_sample_file)

hh_sample = convert_to_str(hh_marg,hh_sample)
p_sample = convert_to_str(p_marg,p_sample)

# %%
hh_sample
# Out:
#        sample_geog               BEDRD                        DWTD  \
# 0                1          2 bedrooms  Occupied private dwellings
# 1                1          4 bedrooms  Occupied private dwellings
# 2                1          3 bedrooms  Occupied private dwellings
# 3                1          Not stated  Occupied private dwellings
# 4                1          4 bedrooms  Occupied private dwellings
# 5                1          4 bedrooms  Occupied private dwellings
# 6                1  5 or more bedrooms  Occupied private dwellings
# 7                1          4 bedrooms  Occupied private dwellings
# 8                1          4 bedrooms  Occupied private dwellings
# 9                1          3 bedrooms  Occupied private dwellings
# 10               1          3 bedrooms  Occupied private dwellings
# 11               1          3 bedrooms  Occupied private dwellings
# 12               1           1 bedroom  Occupied private dwellings
# 13               1      Not applicable       Non-private dwellings
# 14               1          3 bedrooms  Occupied private dwellings
# 15               1          4 bedrooms  Occupied private dwellings
# 16               1  5 or more bedrooms  Occupied private dwellings
# 17               1          3 bedrooms  Occupied private dwellings
# 18               1          4 bedrooms  Occupied private dwellings
# 19               1          4 bedrooms  Occupied private dwellings
# 20               1          2 bedrooms  Occupied private dwellings
# 21               1           1 bedroom  Occupied private dwellings
# 22               1      Not applicable       Non-private dwellings
# 23               1          3 bedrooms  Occupied private dwellings
# 24               1          3 bedrooms  Occupied private dwellings
# 25               1          3 bedrooms  Occupied private dwellings
# 26               1      Not applicable       Non-private dwellings
# 27               1          3 bedrooms  Occupied private dwellings
# 28               1          3 bedrooms  Occupied private dwellings
# 29               1          3 bedrooms  Occupied private dwellings
# ...            ...                 ...                         ...
# 87768           56          4 bedrooms  Occupied private dwellings
# 87769           56          3 bedrooms  Occupied private dwellings
# 87770           56          4 bedrooms  Occupied private dwellings
# 87771           56          Not stated  Occupied private dwellings
# 87772           56          3 bedrooms  Occupied private dwellings
# 87773           56  5 or more bedrooms  Occupied private dwellings
# 87774           56          4 bedrooms  Occupied private dwellings
# 87775           56          4 bedrooms  Occupied private dwellings
# 87776           56          3 bedrooms  Occupied private dwellings
# 87777           56          4 bedrooms  Occupied private dwellings
# 87778           56          4 bedrooms  Occupied private dwellings
# 87779           56  5 or more bedrooms  Occupied private dwellings
# 87780           56          4 bedrooms  Occupied private dwellings
# 87781           56          4 bedrooms  Occupied private dwellings
# 87782           56          3 bedrooms  Occupied private dwellings
# 87783           56          4 bedrooms  Occupied private dwellings
# 87784           56           1 bedroom  Occupied private dwellings
# 87785           56          3 bedrooms  Occupied private dwellings
# 87786           56          Not stated  Occupied private dwellings
# 87787           56          4 bedrooms  Occupied private dwellings
# 87788           56          3 bedrooms  Occupied private dwellings
# 87789           56          3 bedrooms  Occupied private dwellings
# 87790           56          3 bedrooms  Occupied private dwellings
# 87791           56          3 bedrooms  Occupied private dwellings
# 87792           56          4 bedrooms  Occupied private dwellings
# 87793           56          4 bedrooms  Occupied private dwellings
# 87794           56  5 or more bedrooms  Occupied private dwellings
# 87795           56          2 bedrooms  Occupied private dwellings
# 87796           56          3 bedrooms  Occupied private dwellings
# 87797           56          4 bedrooms  Occupied private dwellings
#
#                          HIND           MRERD            NPRD  \
# 0               $1,500-$1,999   $2,400-$2,599               2
# 1               $2,000-$2,499   $1,800-$1,999               2
# 2                   $400-$599  Not applicable               3
# 3              Not applicable  Not applicable               1
# 4                   $300-$399  Not applicable               1
# 5               $2,500-$2,999   $3,000-$3,999               4
# 6               $1,000-$1,249  Not applicable               1
# 7               $2,000-$2,499   $2,600-$2,999               3
# 8               $1,000-$1,249  Not applicable               2
# 9                   $800-$999  Not applicable               1
# 10              $1,000-$1,249  Not applicable               5
# 11                  $400-$599  Not applicable               2
# 12                  $300-$399  Not applicable               1
# 13             Not applicable  Not applicable  Not applicable
# 14                  $300-$399  Not applicable               1
# 15                  $800-$999   $2,200-$2,399               4
# 16              $2,000-$2,499  Not applicable               2
# 17             $4,000 or more  Not applicable               2
# 18              $3,000-$3,499  Not applicable               2
# 19              $2,500-$2,999  Not applicable               2
# 20                  $300-$399  Not applicable               2
# 21                  $400-$599  Not applicable               1
# 22             Not applicable  Not applicable  Not applicable
# 23                  $600-$799  Not applicable               2
# 24              $1,500-$1,999  Not applicable               2
# 25              $1,500-$1,999  Not applicable               2
# 26             Not applicable  Not applicable  Not applicable
# 27                  $400-$599  Not applicable               1
# 28                  $800-$999  Not applicable               1
# 29              $2,000-$2,499  Not applicable               4
# ...                       ...             ...             ...
# 87768           $3,000-$3,499   $1,600-$1,799               4
# 87769           $1,500-$1,999  Not applicable               2
# 87770   Partial income stated   $2,000-$2,199               3
# 87771          Not applicable  Not applicable               1
# 87772           $2,500-$2,999  Not applicable               1
# 87773               $300-$399  Not applicable               3
# 87774               $800-$999   $3,000-$3,999               2
# 87775           $3,000-$3,499  Not applicable               4
# 87776          $4,000 or more   $3,000-$3,999               4
# 87777           $2,500-$2,999  Not applicable               4
# 87778           $1,500-$1,999  Not applicable               2
# 87779           $3,000-$3,499   $3,000-$3,999               2
# 87780           $2,500-$2,999  Not applicable               2
# 87781           $2,000-$2,499   $1,600-$1,799               4
# 87782   Partial income stated   $1,800-$1,999               3
# 87783           $3,000-$3,499   $2,200-$2,399               3
# 87784  All incomes not stated  Not applicable               2
# 87785           $2,500-$2,999  Not applicable               4
# 87786          Not applicable  Not applicable               2
# 87787   Partial income stated   $1,800-$1,999               4
# 87788           $1,500-$1,999  Not applicable               2
# 87789           $3,500-$3,999  Not applicable               2
# 87790           $2,000-$2,499   $1,800-$1,999               3
# 87791           $3,000-$3,499   $2,600-$2,999               2
# 87792           $1,500-$1,999      Not stated               2
# 87793           $2,500-$2,999  Not applicable               1
# 87794          $4,000 or more  Not applicable               5
# 87795           $1,000-$1,249       $300-$449               2
# 87796   Partial income stated  Not applicable               4
# 87797           $2,000-$2,499   $3,000-$3,999               2
#
#                                                   STRD  \
# 0                                       Separate house
# 1                                       Separate house
# 2                                       Separate house
# 3                                       Separate house
# 4                                       Separate house
# 5                                       Separate house
# 6                                       Separate house
# 7                                       Separate house
# 8                                       Separate house
# 9                                       Separate house
# 10                                      Separate house
# 11                                      Separate house
# 12                                      Separate house
# 13                                      Not applicable
# 14     Semi-detached, row or terrace house, town house
# 15                                      Separate house
# 16                                      Separate house
# 17                                      Separate house
# 18                                      Separate house
# 19                                      Separate house
# 20                                      Separate house
# 21                                      Separate house
# 22                                      Not applicable
# 23                                      Separate house
# 24                                      Separate house
# 25                                      Separate house
# 26                                      Not applicable
# 27     Semi-detached, row or terrace house, town house
# 28                                      Separate house
# 29                                      Separate house
# ...                                                ...
# 87768                                   Separate house
# 87769                                   Separate house
# 87770                                   Separate house
# 87771                                   Separate house
# 87772                                   Separate house
# 87773                                   Separate house
# 87774                                   Separate house
# 87775                                   Separate house
# 87776                                   Separate house
# 87777                                   Separate house
# 87778                                   Separate house
# 87779                                   Separate house
# 87780                                   Separate house
# 87781                                   Separate house
# 87782                                   Separate house
# 87783                                   Separate house
# 87784                                   Separate house
# 87785                                   Separate house
# 87786                                   Separate house
# 87787                                   Separate house
# 87788                                   Separate house
# 87789                                   Separate house
# 87790                                   Separate house
# 87791                                   Separate house
# 87792                                   Separate house
# 87793                                   Separate house
# 87794                                   Separate house
# 87795  Semi-detached, row or terrace house, town house
# 87796                                   Separate house
# 87797                                   Separate house
#
#                                                     TEND  \
# 0      Owned with a mortgage (includes being purchase...
# 1      Owned with a mortgage (includes being purchase...
# 2             Rented (includes being occupied rent free)
# 3                                             Not stated
# 4                                         Owned outright
# 5      Owned with a mortgage (includes being purchase...
# 6                                         Owned outright
# 7      Owned with a mortgage (includes being purchase...
# 8                                         Owned outright
# 9             Rented (includes being occupied rent free)
# 10            Rented (includes being occupied rent free)
# 11                                        Owned outright
# 12     Other (includes being occupied under life tenu...
# 13                                        Not applicable
# 14                                        Owned outright
# 15     Owned with a mortgage (includes being purchase...
# 16                                        Owned outright
# 17                                        Owned outright
# 18                                        Owned outright
# 19                                        Owned outright
# 20            Rented (includes being occupied rent free)
# 21                                        Owned outright
# 22                                        Not applicable
# 23                                        Owned outright
# 24                                        Owned outright
# 25                                        Owned outright
# 26                                        Not applicable
# 27                                        Owned outright
# 28                                        Owned outright
# 29            Rented (includes being occupied rent free)
# ...                                                  ...
# 87768  Owned with a mortgage (includes being purchase...
# 87769                                     Owned outright
# 87770  Owned with a mortgage (includes being purchase...
# 87771                                         Not stated
# 87772                                     Owned outright
# 87773         Rented (includes being occupied rent free)
# 87774  Owned with a mortgage (includes being purchase...
# 87775                                     Owned outright
# 87776  Owned with a mortgage (includes being purchase...
# 87777                                     Owned outright
# 87778                                     Owned outright
# 87779  Owned with a mortgage (includes being purchase...
# 87780                                     Owned outright
# 87781  Owned with a mortgage (includes being purchase...
# 87782  Owned with a mortgage (includes being purchase...
# 87783  Owned with a mortgage (includes being purchase...
# 87784                                     Owned outright
# 87785         Rented (includes being occupied rent free)
# 87786                                         Not stated
# 87787  Owned with a mortgage (includes being purchase...
# 87788         Rented (includes being occupied rent free)
# 87789                                     Owned outright
# 87790  Owned with a mortgage (includes being purchase...
# 87791  Owned with a mortgage (includes being purchase...
# 87792  Owned with a mortgage (includes being purchase...
# 87793                                     Owned outright
# 87794                                     Owned outright
# 87795  Owned with a mortgage (includes being purchase...
# 87796                                         Not stated
# 87797  Owned with a mortgage (includes being purchase...
#
#                           VEHRD
# 0              2 motor vehicles
# 1              2 motor vehicles
# 2              2 motor vehicles
# 3                    Not stated
# 4               1 motor vehicle
# 5              2 motor vehicles
# 6               1 motor vehicle
# 7              2 motor vehicles
# 8              2 motor vehicles
# 9               1 motor vehicle
# 10              1 motor vehicle
# 11             2 motor vehicles
# 12                         None
# 13               Not applicable
# 14                         None
# 15              1 motor vehicle
# 16              1 motor vehicle
# 17             2 motor vehicles
# 18              1 motor vehicle
# 19              1 motor vehicle
# 20             3 motor vehicles
# 21              1 motor vehicle
# 22               Not applicable
# 23              1 motor vehicle
# 24             2 motor vehicles
# 25             2 motor vehicles
# 26               Not applicable
# 27              1 motor vehicle
# 28              1 motor vehicle
# 29              1 motor vehicle
# ...                         ...
# 87768          2 motor vehicles
# 87769          3 motor vehicles
# 87770          2 motor vehicles
# 87771                Not stated
# 87772           1 motor vehicle
# 87773                Not stated
# 87774          2 motor vehicles
# 87775          3 motor vehicles
# 87776          3 motor vehicles
# 87777          2 motor vehicles
# 87778          2 motor vehicles
# 87779          2 motor vehicles
# 87780          2 motor vehicles
# 87781  4 or more motor vehicles
# 87782           1 motor vehicle
# 87783          2 motor vehicles
# 87784          2 motor vehicles
# 87785          2 motor vehicles
# 87786                Not stated
# 87787          2 motor vehicles
# 87788          2 motor vehicles
# 87789          2 motor vehicles
# 87790          2 motor vehicles
# 87791          2 motor vehicles
# 87792          2 motor vehicles
# 87793           1 motor vehicle
# 87794  4 or more motor vehicles
# 87795          2 motor vehicles
# 87796          2 motor vehicles
# 87797          3 motor vehicles
#
# [87798 rows x 9 columns]

# %%
hh_marg.head()
# Out:
# cat_name       BEDRD                                                      \
# cat_values 1 bedroom 2 bedrooms 3 bedrooms 4 bedrooms 5 or more bedrooms
# 1.0            138.0      618.0     1652.0     1036.0              224.0
# 2.0             80.0      450.0     1030.0      610.0              122.0
# 3.0            146.0      462.0     1458.0      888.0              204.0
# 4.0            240.0      904.0     1990.0     1010.0              210.0
# 5.0            152.0      498.0     1374.0      768.0              162.0
#
# cat_name                                                         \
# cat_values None (includes bedsitters) Not applicable Not stated
# 1.0                              20.0          478.0      234.0
# 2.0                              12.0          114.0      120.0
# 3.0                              12.0          264.0      196.0
# 4.0                              40.0          354.0      240.0
# 5.0                              26.0          332.0      216.0
#
# cat_name                    DWTD                             ...  \
# cat_values Non-private dwellings Occupied private dwellings  ...
# 1.0                        478.0                     3922.0  ...
# 2.0                        114.0                     2424.0  ...
# 3.0                        264.0                     3366.0  ...
# 4.0                        354.0                     4634.0  ...
# 5.0                        332.0                     3196.0  ...
#
# cat_name             TEND  \
# cat_values Owned outright
# 1.0                1396.0
# 2.0                 840.0
# 3.0                1142.0
# 4.0                1840.0
# 5.0                1128.0
#
# cat_name                                                                             \
# cat_values Owned with a mortgage (includes being purchased under a rent/buy scheme)
# 1.0                                                    1262.0
# 2.0                                                     772.0
# 3.0                                                    1124.0
# 4.0                                                    1214.0
# 5.0                                                     908.0
#
# cat_name                                                        VEHRD  \
# cat_values Rented (includes being occupied rent free) 1 motor vehicle
# 1.0                                             954.0          1300.0
# 2.0                                             656.0           902.0
# 3.0                                             882.0          1114.0
# 4.0                                            1272.0          1920.0
# 5.0                                             906.0          1136.0
#
# cat_name                                                                      \
# cat_values 2 motor vehicles 3 motor vehicles 4 or more motor vehicles   None
# 1.0                  1454.0            406.0                    214.0  240.0
# 2.0                   806.0            236.0                     90.0  224.0
# 3.0                  1230.0            388.0                    186.0  236.0
# 4.0                  1498.0            402.0                    142.0  358.0
# 5.0                  1046.0            310.0                    160.0  276.0
#
# cat_name
# cat_values Not applicable Not stated
# 1.0                 478.0      308.0
# 2.0                 114.0      166.0
# 3.0                 264.0      212.0
# 4.0                 354.0      314.0
# 5.0                 332.0      268.0
#
# [5 rows x 76 columns]

# %%
p_marg.head()
# Out:
# cat_name   CHCAREP                                 HRSP                       \
# cat_values       1       2      3       4     5       1      2      3      4
# 1.0         5186.0  2180.0  748.0  1926.0  34.0  5864.0  460.0  386.0  462.0
# 2.0         2974.0  1498.0  392.0  1268.0  34.0  3670.0  332.0  252.0  310.0
# 3.0         4186.0  2092.0  530.0  1806.0  34.0  4926.0  414.0  338.0  374.0
# 4.0         6238.0  2326.0  634.0  1964.0  64.0  7132.0  570.0  474.0  590.0
# 5.0         3812.0  1836.0  554.0  1722.0  22.0  4676.0  354.0  306.0  334.0
#
# cat_name           ...   OCCP                                                  \
# cat_values      5  ...      4      5      6      7      8     9      10    11
# 1.0         724.0  ...  506.0  552.0  372.0  294.0  492.0  96.0  5666.0  34.0
# 2.0         532.0  ...  324.0  368.0  246.0  164.0  272.0  44.0  3554.0  34.0
# 3.0         636.0  ...  348.0  470.0  346.0  468.0  430.0  70.0  4748.0  34.0
# 4.0         786.0  ...  470.0  586.0  462.0  234.0  460.0  64.0  6954.0  64.0
# 5.0         588.0  ...  378.0  394.0  272.0  236.0  412.0  68.0  4534.0  22.0
#
# cat_name      SEXP
# cat_values       1       2
# 1.0         5106.0  4968.0
# 2.0         2974.0  3192.0
# 3.0         4302.0  4346.0
# 4.0         5486.0  5740.0
# 5.0         3924.0  4022.0
#
# [5 rows x 66 columns]

# %%
p_sample.head()
# Out:
#    sample_geog  AGEP CHCAREP HRSP INCP INDP OCCP SEXP
# 0            1    31       1    2   11   16    2    2
# 1            1    20       1    1    3   22   10    1
# 2            1    25       1    7    9   13    1    1
# 3            1    26       1    5    8   17    2    2
# 4            1    28       2    3    6   16    2    2

# %%
p_sample.columns
# Out:
# Index(['sample_geog', 'AGEP', 'CHCAREP', 'HRSP', 'INCP', 'INDP', 'OCCP',
#        'SEXP'],
#       dtype='object')

# %%
for i in p_marg.columns:
    print(i)
# Out:
# ('CHCAREP', '1')
# ('CHCAREP', '2')
# ('CHCAREP', '3')
# ('CHCAREP', '4')
# ('CHCAREP', '5')
# ('HRSP', '1')
# ('HRSP', '2')
# ('HRSP', '3')
# ('HRSP', '4')
# ('HRSP', '5')
# ('HRSP', '6')
# ('HRSP', '7')
# ('HRSP', '8')
# ('HRSP', '9')
# ('HRSP', '10')
# ('INCP', '1')
# ('INCP', '2')
# ('INCP', '3')
# ('INCP', '4')
# ('INCP', '5')
# ('INCP', '6')
# ('INCP', '7')
# ('INCP', '8')
# ('INCP', '9')
# ('INCP', '10')
# ('INCP', '11')
# ('INCP', '12')
# ('INCP', '13')
# ('INCP', '14')
# ('INCP', '15')
# ('INDP', '1')
# ('INDP', '2')
# ('INDP', '3')
# ('INDP', '4')
# ('INDP', '5')
# ('INDP', '6')
# ('INDP', '7')
# ('INDP', '8')
# ('INDP', '9')
# ('INDP', '10')
# ('INDP', '11')
# ('INDP', '12')
# ('INDP', '13')
# ('INDP', '14')
# ('INDP', '15')
# ('INDP', '16')
# ('INDP', '17')
# ('INDP', '18')
# ('INDP', '19')
# ('INDP', '20')
# ('INDP', '21')
# ('INDP', '22')
# ('INDP', '23')
# ('OCCP', '1')
# ('OCCP', '2')
# ('OCCP', '3')
# ('OCCP', '4')
# ('OCCP', '5')
# ('OCCP', '6')
# ('OCCP', '7')
# ('OCCP', '8')
# ('OCCP', '9')
# ('OCCP', '10')
# ('OCCP', '11')
# ('SEXP', '1')
# ('SEXP', '2')

# %%
p_sample.dtypes
# Out:
# sample_geog    int64
# AGEP           int64
# CHCAREP        int64
# HRSP           int64
# INCP           int64
# INDP           int64
# OCCP           int64
# SEXP           int64
# dtype: object

# %% [markdown]
# #### Iterate over all marginals in the geography crosswalk and synthesize in-line

# %%
all_households, all_persons, all_stats = zs.synthesize_all_zones(hh_marg, p_marg, hh_sample, p_sample, xwalk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9516f1d61e11> in <module>
# ----> 1 all_households, all_persons, all_stats = zs.synthesize_all_zones(hh_marg, p_marg, hh_sample, p_sample, xwalk)
#
# ~\Anaconda3\lib\site-packages\synthpop\zone_synthesizer.py in synthesize_all_zones(hh_marg, p_marg, hh_sample, p_sample, xwalk)
#      84     for geogs in xwalk:
#      85         households, people, stats = synthesize_zone(hh_marg, p_marg,
# ---> 86                                                     hh_sample, p_sample, geogs)
#      87         stats_list.append(stats)
#      88         hh_list.append(households)
#
# ~\Anaconda3\lib\site-packages\synthpop\zone_synthesizer.py in synthesize_zone(hh_marg, p_marg, hh_sample, p_sample, xwalk)
#     156     ps, p_jd = cat.joint_distribution(
#     157             p_sample[p_sample.sample_geog == xwalk[1]],
# --> 158             cat.category_combinations(p_marg.columns))
#     159     households, people, people_chisq, people_p = synthesize(
#     160             hh_marg.loc[xwalk[0]], p_marg.loc[xwalk[0]], hh_jd, p_jd, hhs, ps,
#
# ~\Anaconda3\lib\site-packages\synthpop\categorizer.py in joint_distribution(sample_df, category_df, mapping_functions)
#      79     # do the merge to add the category id
#      80     sample_df = pd.merge(sample_df, category_df[["cat_id"]],
# ---> 81                          left_on=category_names, right_index=True)
#      82
#      83     return sample_df, category_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     531         # validate the merge keys dtypes. We may need to coerce
#     532         # to avoid incompat dtypes
# --> 533         self._maybe_coerce_merge_keys()
#     534
#     535         # If argument passed to validate,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#     978                       (inferred_right in string_types and
#     979                        inferred_left not in string_types)):
# --> 980                     raise ValueError(msg)
#     981
#     982             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat

# %%
all_households.head()

# %%
all_households.shape

# %%
all_persons.shape

# %% [markdown]
# #### all_persons.household_id maps person records to all_households.index

# %%
all_persons.head()

# %%
all_stats
